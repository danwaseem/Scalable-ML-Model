# %%
import pandas as pd
import numpy as np
import sklearn.model_selection as model_selection
from sklearn.covariance import EllipticEnvelope
from sklearn.svm import OneClassSVM
from sklearn.ensemble import IsolationForest
avg=0

# %% [markdown]
# ## Ethereuem Address 1
# ### 0x0067f95a79c3c404a9d128168ddfdf3cb70c0852

# %%
dfs = pd.read_csv(r"D:\Desktop\nitk\6th_SEM\ML_Project\transaction_data\1_0x0067f95a79c3c404a9d128168ddfdf3cb70c0852.csv")
dfs1=dfs
display(dfs)
# Out:
#                                                  Txhash  Blockno  \
# 0     0x3c2381ba56d7ac52afe332ef765bc54dea6e39adc376...  4520344
# 1     0xa7b6a71a061f25585d2089ed0b6e6e6d92315f5b0205...  4520499
# 2     0x0e922e72e2015f9d964c03e38b724ce89af21fb02c0b...  4551503
# 3     0xf4e38b199516b53775197097292dc6fdbbd6bd280abb...  4556239
# 4     0xa3062f463750a33d9abc2a889e2fa6006341459eaef0...  4556641
# ...                                                 ...      ...
# 3079  0x4d60eb19fb7ae5b36d3e2424ba7a2a6ce7b59257600e...  8574536
# 3080  0x33ffe7eb6b23d79da4c09c4cae78d97a4b0c0bed8da4...  8574545
# 3081  0x66301c137fd34bb11697e78c6ba50cc49c5ef5979618...  8574599
# 3082  0x355c02d1b97b3c87c9235279e11f751146a30a11d0c8...  8575523
# 3083  0x7fbf4160c9c2ae7431334e2cf1ca47a75934388b76b9...  8579448
#
#       UnixTimestamp                DateTime  \
# 0        1510237329    11/9/2017 2:22:09 PM
# 1        1510239325    11/9/2017 2:55:25 PM
# 2        1510668562   11/14/2017 2:09:22 PM
# ...

# %% [markdown]
# ### Pre-Processing

# %%
dfs=dfs.drop(['Txhash','Blockno','UnixTimestamp','DateTime','From','To'],axis=1)
dfs=dfs.dropna()
display(dfs)
# Out:
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# 0       6.553600e-14     0.000221     0.047815                 319.66
# 1       1.786700e-02     0.000252     0.054646                 319.66
# 2       8.488310e-01     0.000420     0.091077                 334.72
# 3       8.307040e+00     0.000315     0.068308                 331.20
# 4       8.310500e-01     0.000420     0.091077                 331.20
# ...              ...          ...          ...                    ...
# 3079    2.447829e-01     0.000441     0.095631                 210.50
# 3080    1.225749e+00     0.000420     0.091077                 210.50
# 3081    1.019297e+01     0.000420     0.091077                 210.50
# 3082    1.003796e+00     0.000420     0.091077                 210.50
# 3083    1.007951e+00     0.000630     0.136616                 221.29
#
# [3084 rows x 4 columns]

# %% [markdown]
# ### Splitting the data

# %%
train, test = model_selection.train_test_split(dfs,test_size=0.25, random_state=101)
print("TESTING DATA")
display(train)
print("TRAINING DATA")
display(test)
# Out:
# TESTING DATA
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# 1614        0.485686     0.000063     0.013662                 456.56
# 1508        0.126143     0.000147     0.031877                 429.58
# 904         1.009954     0.000420     0.091077                 865.27
# 495         1.108709     0.001659     0.359754                1136.11
# 1664        0.366195     0.000126     0.027323                 278.31
# ...              ...          ...          ...                    ...
# 599         0.171140     0.001680     0.364308                1385.02
# 1599        2.355534     0.000084     0.018215                 479.47
# 1361        0.081842     0.000252     0.054646                 640.84
# 1547        2.537942     0.000315     0.068308                 432.69
# 863         0.164118     0.000462     0.100185                 785.01
#
# [2313 rows x 4 columns]
# TRAINING DATA
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# ...

# %% [markdown]
# ### Training and testing the model

# %%
model = IsolationForest(contamination=0.01,random_state=101)
model.fit(train)

y_pred1=model.predict(test)
acc=(y_pred1==-1).sum()/test.shape[0]
print("The Accuracy of the anamoly detection unit (Isolation forest) is", (1-acc)*100,"%")
# Out:
# The Accuracy of the anamoly detection unit (Isolation forest) is 99.09208819714657 %

# %%
model=OneClassSVM(nu=0.01)
model.fit(train)

y_pred2=model.predict(test)
acc=(y_pred2==-1).sum()/test.shape[0]
print("The Accuracy of the the anamoly detection (One Class SVM) unit is ", (1-acc)*100,"%")
# Out:
# The Accuracy of the the anamoly detection (One Class SVM) unit is  97.4059662775616 %

# %%
model = EllipticEnvelope(contamination=0.02)
model.fit(train)

y_pred3=model.predict(test)
acc=(y_pred3==-1).sum()/test.shape[0]
print("The Accuracy of the the anamoly detection (Minimum Coeriance Determinant) unit is ", (1-acc)*100,"%")
# Out:
# D:\Users\danis\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:647: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# D:\Users\danis\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:166: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-52.602543456437004 > -52.639300304994727). You may want to try with a higher value of support_fraction (current value: 0.503).
#   warnings.warn("Determinant has increased; this should not happen: "
# D:\Users\danis\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:166: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.553181757204079 > -51.620887623625833). You may want to try with a higher value of support_fraction (current value: 0.503).
# ...

# %%
print("Isolation factor has an higher accuracy than the others, so we will use Isolation forest for the remaining user transaction.")
# Out:
# Isolation factor has an higher accuracy than the others, so we will use Isolation forest for the remaining user transaction.

# %%
model = IsolationForest(contamination=0.01,random_state=101)
train['anamoly']=model.fit_predict(train)
a=train.loc[train['anamoly']==-1]
test['anamoly']=model.predict(test)
# Out:
# <ipython-input-9-8d22b4d3fdd8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['anamoly']=model.fit_predict(train)
# <ipython-input-9-8d22b4d3fdd8>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['anamoly']=model.predict(test)

# %% [markdown]
# ### Transactions which has been marked as anamoly

# %%
b=test.loc[test['anamoly']==-1]

c=pd.concat([a,b])
merged_left = pd.merge(left=dfs1, right=c, how='right',sort=True)
display(merged_left)
# Out:
#                                                Txhash  Blockno  UnixTimestamp  \
# 0   0x53b44ca1f6ce0e8712052a7fc9fb5475592badea1e77...  4886216     1515602909
# 1   0xb305e09d6174628dcf2468ca2e4195e6899a6e89836b...  5893188     1530545766
# 2   0x66aa15ffd00b504d2c3bafa1634569191408b39dc240...  4891232     1515683166
# 3   0x0af7936edc68b89f3aa8bd092e280bf0c39084fc2495...  4859147     1515171755
# 4   0xa65757bc258b6ae3623ca3623cd4ff6a77b26f6e50c6...  4886585     1515608415
# 5   0xb62c36a5427a34445b63ba18f76f93dd5bc99e6544ee...  4858903     1515167713
# 6   0x4d161b5793267695a7e8d44e720a2bc8c587307b3612...  4859194     1515172458
# 7   0xa61c28743ba7806c252ff7260c11a92dcb963ab5cbd0...  4859200     1515172518
# 8   0xd2bfe9fd38d976b024b352d54c718e5774ca45e2dcc5...  5886493     1530447902
# 9   0x5d82a7705d42f63de972f52dcd45bfc122cceee31046...  5893178     1530545643
# 10  0xb691afe4789ff631dba7617c2f18c92d2005d2361500...  4891608     1515689029
# ...

# %% [markdown]
# ## Ethereuem Address 2
# ### 0xf1Cf296C11d3b010E6dd3D48B6C5AaeD613E96f1

# %%
dfs = pd.read_csv(r"D:\Desktop\nitk\6th_SEM\ML_Project\transaction_data\2_0xf1Cf296C11d3b010E6dd3D48B6C5AaeD613E96f1.csv")
dfs1=dfs
display(dfs)
# Out:
#                                                  Txhash  Blockno  \
# 0     0x43c312c34a764e39ecccb2e2e1942f89fbf3c53a872c...  5164321
# 1     0x28299a1d7f725289c010635f649f8b1ce87313488fe2...  5164347
# 2     0xcbc448bcaf85c5da4d1dc630f24014a440b1f6da2d94...  5164349
# 3     0x93c13ff7248608b15564e82122692a2346aab68e510d...  5164349
# 4     0xc274637b51acd42689d1549bbb9d016ac0a0e26d3f69...  5165447
# ...                                                 ...      ...
# 3153  0x8049fb2179776ae1e4ba1cd007a3311de6a890a7c780...  8577064
# 3154  0x678877d84010290545d82cea4f75b829fa6a204a7b06...  8578873
# 3155  0xfaa2234a8c61f3a4ccb7e6872c875d7da64a3ca7398c...  8580144
# 3156  0xc2ce91df2f602090e6657c9d25853ce6148ff6de94e2...  8580144
# 3157  0x4dfa83e2364fed8b59809e81488d30c0c3101892333d...  8584557
#
#       UnixTimestamp               DateTime  \
# 0        1519719165   2/27/2018 8:12:45 AM
# 1        1519719562   2/27/2018 8:19:22 AM
# 2        1519719588   2/27/2018 8:19:48 AM
# ...

# %% [markdown]
# ### Pre-Processing

# %%
dfs=dfs.drop(['Txhash','Blockno','UnixTimestamp','DateTime','From','To'],axis=1)
dfs=dfs.dropna()
display(dfs)
# Out:
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# 0           0.010000     0.000168     0.036523                 871.58
# 1           5.000000     0.000168     0.036523                 871.58
# 2           0.984009     0.000168     0.036523                 871.58
# 3           2.156282     0.000168     0.036523                 871.58
# 4           1.244525     0.000168     0.036523                 871.58
# ...              ...          ...          ...                    ...
# 3152        2.455581     0.000483     0.104946                 210.50
# 3153        4.800000     0.000416     0.090345                 221.29
# 3154       15.000000     0.000462     0.100429                 221.29
# 3155        0.987000     0.000462     0.100383                 221.29
# 3156        1.802546     0.000462     0.100383                 221.29
#
# [3157 rows x 4 columns]

# %% [markdown]
# ### Splitting the data

# %%
train, test = model_selection.train_test_split(dfs,test_size=0.25, random_state=101)
display(train)
display(test)
# Out:
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# 384         5.239803     0.000042     0.009131                 486.25
# 2773        3.200000     0.000231     0.050192                 264.71
# 2875        0.012034     0.000105     0.022814                 333.76
# 2261        1.544510     0.000046     0.010042                 131.56
# 323         4.690377     0.000042     0.009131                 557.57
# ...              ...          ...          ...                    ...
# 599         2.411215     0.000021     0.004565                 494.96
# 1599       32.200000     0.000105     0.022827                 499.06
# 1361        4.265136     0.000210     0.045654                 608.23
# 1547       27.688654     0.001197     0.260228                 467.19
# 863         0.865681     0.000079     0.017180                 683.02
#
# [2367 rows x 4 columns]
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# ...

# %% [markdown]
# ### Training and testing the model

# %%
model = IsolationForest(contamination=0.01,random_state=101)
train['anamoly']=model.fit_predict(train)
a=train.loc[train['anamoly']==-1]
test['anamoly']=model.predict(test)
y_pred=test['anamoly']
acc=(y_pred==-1).sum()/test.shape[0]
print("The Accuracy of the following anamoly detection unit is ", (1-acc)*100,"%")
avg+=acc
# Out:
# The Accuracy of the following anamoly detection unit is  99.74683544303798 %
# <ipython-input-14-bf5b250f45fd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['anamoly']=model.fit_predict(train)
# <ipython-input-14-bf5b250f45fd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['anamoly']=model.predict(test)

# %% [markdown]
# ### Transactions which has been marked as anamoly

# %%
(y_pred==-1).sum()
b=test.loc[test['anamoly']==-1]

c=pd.concat([a,b])
merged_left = pd.merge(left=dfs1, right=c, how='right',sort=True)
display(merged_left)
# Out:
#                                                Txhash  Blockno  UnixTimestamp  \
# 0   0xa8565e73916ee6aaa186d56f100fec789efc4a2fcb9e...  5697243     1527600561
# 1   0x735c730db2f4b5025ceb4c700a8778249cea5eb60f03...  5786832     1528970575
# 2   0x787cde595b76dbcc1af13c90597c13188d0776c49ba3...  5692632     1527530493
# 3   0xaf9248429052f3cf1bbdc81823cc07d8b28d4322ac44...  5692322     1527525702
# 4   0xa6df9a8b2bf96e1c12e6ee7d5bc5c5f31a9a5c1b4af9...  5786819     1528970392
# 5   0x1f2b6a06a4d1d2828e798d118f2e6607693458bc97f1...  5886087     1530441859
# 6   0x8097c3e45d6353b22bd1e0938e816bcb03ecbf5b0c08...  5692620     1527530346
# 7   0x873d957582c155e16ffeb5a131b4444fc799fdf003c1...  5881318     1530371336
# 8   0x1d7a276e0c54cec2d2458de5690d3b618e80c3a7199f...  5891521     1530521095
# 9   0x1f8ec46766febcd3e3a9c7f8a8016c75a27c6a1cf639...  5787034     1528973715
# 10  0x4ebd3b0305d7b2e0f70400db937576267e41cf5ce20c...  5787040     1528973831
# ...

# %% [markdown]
# ## Ethereuem Address 3
# ### 0x7D8eEc47d19bF4AD805CcA67a6701611a06ed151

# %%
dfs = pd.read_csv(r"D:\Desktop\nitk\6th_SEM\ML_Project\transaction_data\3_0x7D8eEc47d19bF4AD805CcA67a6701611a06ed151.csv")
dfs1=dfs
display(dfs)
# Out:
#                                                  Txhash  Blockno  \
# 0     0xc5d14895dfd9d4f8283119d1f3cfe1221c0b1356ed71...  6881487
# 1     0xb7f62c1f74155d1c09a44c2f783e2246c1d238150e7f...  6881643
# 2     0xae4288f9499c99eca596e9a712550090f51521602224...  6881783
# 3     0x400d89c0b364f1b5677956c8566dcf9d7e3dae8b12b5...  6881902
# 4     0x0f9660e249a864dc5d791cba24c554bc5513dcb478c8...  6884388
# ...                                                 ...      ...
# 3516  0xf106a6d77999e9a11541b8d0077b6817f0dd7578cadf...  8582451
# 3517  0x8851ca7cd2b4341529ca7b6584a8e3a1dce69954ba8f...  8583415
# 3518  0x8a6ca4a76f39bdb8bb4152e3cf018cb8e31b8dd70129...  8585171
# 3519  0x7730312f4461d62247fd260df3b9eae77e7301d35c99...  8585218
# 3520  0x5d0dc4f04420ab3a6837eb3ec647f5559726c4de8050...  8585235
#
#       UnixTimestamp                DateTime  \
# 0        1544739316  12/13/2018 10:15:16 PM
# 1        1544741543  12/13/2018 10:52:23 PM
# 2        1544743413  12/13/2018 11:23:33 PM
# ...

# %% [markdown]
# ### Pre-Processing

# %%
dfs=dfs.drop(['Txhash','Blockno','UnixTimestamp','DateTime','From','To'],axis=1)
dfs=dfs.dropna()
display(dfs)
# Out:
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# 0           0.045000     0.000151     0.032854                  86.39
# 1           0.002000     0.000143     0.031029                  86.39
# 2          19.591215     0.000097     0.020990                  86.39
# 3         236.635115     0.000168     0.036505                  86.39
# 4           0.506612     0.000210     0.045631                  83.90
# ...              ...          ...          ...                    ...
# 3516        2.165671     0.000326     0.070850                 221.29
# 3517        5.718073     0.000756     0.164294                1240.14
# 3518        1.000000     0.000756     0.164294                 216.88
# 3519        2.876773     0.000756     0.164294                 623.91
# 3520        0.944438     0.000756     0.164294                 204.75
#
# [3521 rows x 4 columns]

# %% [markdown]
# ### Splitting the data

# %%
train, test = model_selection.train_test_split(dfs,test_size=0.25, random_state=101)
display(train)
display(test)
# Out:
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# 1921        0.483918     0.000126     0.027382                 267.42
# 482         0.142608     0.000168     0.036505                 119.46
# 3008        0.153849     0.000109     0.023731                 208.62
# 50          1.165000     0.000126     0.027379                 116.43
# 579         0.576848     0.000126     0.027379                 144.40
# ...              ...          ...          ...                    ...
# 599         0.028814     0.000210     0.045631                 149.04
# 1599        2.390392     0.000531     0.115446                 248.64
# 1361        0.225094     0.000126     0.027379                 161.29
# 1547        3.754528     0.000042     0.009126                 195.83
# 863         0.264601     0.000084     0.018252                 139.46
#
# [2640 rows x 4 columns]
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# ...

# %% [markdown]
# ### Training and testing the model

# %%
model = IsolationForest(contamination=0.01,random_state=101)
train['anamoly']=model.fit_predict(train)
a=train.loc[train['anamoly']==-1]
test['anamoly']=model.predict(test)
y_pred=test['anamoly']
acc=(y_pred==-1).sum()/test.shape[0]
print("The Accuracy of the following anamoly detection unit is ", (1-acc)*100,"%")
avg+=acc
# Out:
# The Accuracy of the following anamoly detection unit is  99.09194097616346 %
# <ipython-input-19-bf5b250f45fd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['anamoly']=model.fit_predict(train)
# <ipython-input-19-bf5b250f45fd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['anamoly']=model.predict(test)

# %% [markdown]
# ### Transactions which has been marked as anamoly

# %%
(y_pred==-1).sum()
b=test.loc[test['anamoly']==-1]

c=pd.concat([a,b])
merged_left = pd.merge(left=dfs1, right=c, how='right',sort=True)
display(merged_left)
# Out:
#                                                Txhash  Blockno  UnixTimestamp  \
# 0   0xee7b61923a91fbf48b747851fe691fbf4527ec8b61fb...  8273272     1564776507
# 1   0x0e3c5193730cbdb3b3bbd179d522bcc4d0f16d65419f...  8581612     1568920755
# 2   0x8bc18dc3d6de02a39d34cf9888accc5fda8be954f5b6...  8130526     1562856201
# 3   0x4fc96aac3c90d96a99075e3ddfe7251395753af69c28...  7043013     1547132733
# 4   0x6b477e26bd59ea8f5a21bec50d38fe80d0b7dad2cf03...  7109284     1548168259
# 5   0x47a3775626170ef120e24b990364849b1b097418496b...  8572837     1568801430
# 6   0xf862ba65a242cbf9153235515fd30174ae591c507e42...  8039310     1561629456
# 7   0x860dc718d6c5b577cca8ab758fe3dafec26663cf7425...  7933082     1560195277
# 8   0xeae75836b23ce2dbf5d767d16d78f3158aacba2b47ad...  8572833     1568801410
# 9   0x8b90c3df20e1728b87f4179729da014225b248241e7d...  8163223     1563298289
# 10  0x20f301ef18932b6b1346c493bf70cc4ec733e1fdaa94...  8573281     1568807877
# ...

# %% [markdown]
# ## Ethereuem Address 4
# ### 0xCac76b259AD18A269BE1987c0E8a07A2B855f7b6

# %%
dfs = pd.read_csv(r"D:\Desktop\nitk\6th_SEM\ML_Project\transaction_data\4_0xCac76b259AD18A269BE1987c0E8a07A2B855f7b6.csv")
dfs1=dfs
display(dfs)
# Out:
#                                                  Txhash  Blockno  \
# 0     0x0c2980546a819879ef1abb9d361b6f15d48f44eb6c94...  4393285
# 1     0x878f68b275e9dcc69cdb1c26e14763648b67ecc490c6...  4393611
# 2     0x7cbcb7ae687598f40dda690753674e30368468f29a4a...  4393656
# 3     0x1243339d9d14ccd1501c93a285dafc0d1950c1192db2...  4393670
# 4     0xf15d7a33f5f264af2072ba2bb1087f0ac2b2526c493d...  4393944
# ...                                                 ...      ...
# 4241  0xb3767cdef331664f8bd5771c52d9284c9882af59a50a...  8582280
# 4242  0x97ba7467c0d17d1bf65c199b2896db7653f58a82e74b...  8582289
# 4243  0xfaf938466779ee6de9adf6e46074a4c6684e674a6de4...  8582291
# 4244  0x4f10458b01d9c42ae819c42fbbdce5e50e174fbcb4e9...  8582804
# 4245  0x5008ba994c4859927c17065e0a73b107a3723af5be4e...  8582952
#
#       UnixTimestamp               DateTime  \
# 0        1508469994  10/20/2017 3:26:34 AM
# 1        1508474450  10/20/2017 4:40:50 AM
# 2        1508475119  10/20/2017 4:51:59 AM
# ...

# %% [markdown]
# ### Pre-Processing

# %%
dfs=dfs.drop(['Txhash','Blockno','UnixTimestamp','DateTime','From','To'],axis=1)
dfs=dfs.dropna()
display(dfs)
# Out:
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# 0           0.010000     0.000003     0.000685                 303.08
# 1           0.010000     0.000004     0.000822                 303.08
# 2           0.010000     0.000063     0.013699                 303.08
# 3           0.010000     0.000063     0.013699                 303.08
# 4           0.100000     0.000063     0.013699                 303.08
# ...              ...          ...          ...                    ...
# 4241        0.017052     0.000210     0.045749                 221.29
# 4242        0.007646     0.000210     0.045662                 221.29
# 4243        0.053444     0.000210     0.045662                 221.29
# 4244        0.010401     0.000206     0.044840                 221.29
# 4245        0.105474     0.000096     0.020983                  23.06
#
# [4246 rows x 4 columns]

# %% [markdown]
# ### Splitting the data

# %%
train, test = model_selection.train_test_split(dfs,test_size=0.25, random_state=101)
display(train)
display(test)
# Out:
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# 3427        0.050021     0.000055     0.012055                 302.17
# 182         0.020943     0.000002     0.000457                 296.82
# 2466        0.200141     0.000040     0.008596                 132.89
# 3264        0.007000     0.000105     0.022831                 272.21
# 3135        0.200434     0.000051     0.011014                 244.40
# ...              ...          ...          ...                    ...
# 4079        0.007045     0.000042     0.009132                 175.01
# 4171        0.051176     0.000210     0.045662                 181.19
# 599         0.100008     0.000130     0.028312                 619.04
# 1361        0.050127     0.000092     0.019956                 227.49
# 1547        0.050149     0.000091     0.019727                 195.67
#
# [3184 rows x 4 columns]
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# ...

# %% [markdown]
# ### Training and testing the model

# %%
model = IsolationForest(contamination=0.01,random_state=101)
train['anamoly']=model.fit_predict(train)
a=train.loc[train['anamoly']==-1]
test['anamoly']=model.predict(test)
y_pred=test['anamoly']
acc=(y_pred==-1).sum()/test.shape[0]
print("The Accuracy of the following anamoly detection unit is ", (1-acc)*100,"%")
avg+=acc
# Out:
# The Accuracy of the following anamoly detection unit is  98.7758945386064 %
# <ipython-input-24-bf5b250f45fd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['anamoly']=model.fit_predict(train)
# <ipython-input-24-bf5b250f45fd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['anamoly']=model.predict(test)

# %% [markdown]
# ### Transactions which has been marked as anamoly

# %%
(y_pred==-1).sum()
b=test.loc[test['anamoly']==-1]

c=pd.concat([a,b])
merged_left = pd.merge(left=dfs1, right=c, how='right',sort=True)
display(merged_left)
# Out:
#                                                Txhash  Blockno  UnixTimestamp  \
# 0   0x68d7f5bd00a460f408fecf280085ebbedbfa45c56e84...  5896510     1530594763
# 1   0xfeeba0d81622745b7d4efcbfd2ea81dd867f14921d2f...  6117145     1533829563
# 2   0xc1ae8eb6cf44a4a9b6f0366ec8edccae30bd72ff50f2...  4893484     1515718686
# 3   0x35bb11807cda7664d2d4c5d17af2d0b8c80f9d10e3cb...  4893519     1515719228
# 4   0xac09b15dffe683c3fa68f4085767a00c0ab9b16aa403...  5663288     1527082512
# 5   0xb156d155b15d9a262a412f1c14ad7ac8f01b75bcba38...  5965887     1531617084
# 6   0x49799c16ad384befdc42a7aefc8b56deeff40da9dde3...  5630837     1526584366
# 7   0x265fe3e10aff4d9aca80c4c4f4db0154aa84c8e9b305...  5895996     1530587019
# 8   0xfc1e1f6b87912a2296caf32d9bbc4a4ce451d2c84726...  4731670     1513261900
# 9   0x7a602d4e0c9a3db8a5c3f6f79b35b390e493be6b7b9c...  4731350     1513257191
# 10  0x34e831a44ebf675e43b6ef7764cf6be68ba075fe7625...  4734495     1513305318
# ...

# %% [markdown]
# ## Ethereuem Address 5
# ### 0x491fe5F4724e642C90372B0B95b60c4aC8d13F1c

# %%
dfs = pd.read_csv(r"D:\Desktop\nitk\6th_SEM\ML_Project\transaction_data\5_0x491fe5F4724e642C90372B0B95b60c4aC8d13F1c.csv")
dfs1=dfs
display(dfs)
# Out:
#                                                  Txhash  Blockno  \
# 0     0x56543ac240598267d7460c0eaff1cacbf11b83995217...  6247803
# 1     0xba1b9eb9f44b47bd3c15c2462a8306b231bc16018ed7...  6271387
# 2     0x9218baa943aa565fca93b8f03e6e371b3e0c9a999b37...  6287493
# 3     0xc7d528f0d033ec9265ccfa1227bb862afc5786493175...  6292620
# 4     0xdf9d4a207355fda31a429162a9d987d124a7805b8b8e...  6299494
# ...                                                 ...      ...
# 2202  0xf785449c40f82ad0d817b7fc94abe6f533b87b4110c8...  8580615
# 2203  0x2668921f472e11d98fd64c261ba5a05cb2974327762e...  8582245
# 2204  0x1f3242c550b31f57f693487d0f6cf390e746e83062bc...  8583920
# 2205  0xe691a94e2e9534d449046a9e6e1a36181d61975c8993...  8584697
# 2206  0xb756300534aab98b791c862060daee557b4f391eba58...  8585333
#
#       UnixTimestamp              DateTime  \
# 0        1535736503  8/31/2018 5:28:23 PM
# 1        1536080347   9/4/2018 4:59:07 PM
# 2        1536312262   9/7/2018 9:24:22 AM
# ...

# %% [markdown]
# ### Pre-Processing

# %%
dfs=dfs.drop(['Txhash','Blockno','UnixTimestamp','DateTime','From','To'],axis=1)
dfs=dfs.dropna()
display(dfs)
# Out:
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# 0           1.032400     0.000067     0.014606                 281.66
# 1           0.024880     0.000053     0.011411                 285.23
# 2           0.896288     0.000094     0.020434                 215.14
# 3           0.020870     0.000063     0.013693                 196.77
# 4           0.995000     0.000105     0.022822                 195.99
# ...              ...          ...          ...                    ...
# 2199        3.078591     0.000483     0.104980                 221.29
# 2200        0.200000     0.000441     0.095851                 221.29
# 2201        0.038000     0.000441     0.095851                 221.29
# 2202        1.155600     0.000462     0.100416                 221.29
# 2203       49.538593     0.000280     0.060751                 221.29
#
# [2204 rows x 4 columns]

# %% [markdown]
# ### Splitting the data

# %%
train, test = model_selection.train_test_split(dfs,test_size=0.25, random_state=101)
display(train)
display(test)
# Out:
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# 1806        0.340000     0.000063     0.013693                 219.85
# 258         0.098000     0.000189     0.041079                  95.44
# 1111        1.037715     0.000252     0.054772                 243.46
# 1579        1.000000     0.000021     0.004564                 307.89
# 422         8.928000     0.000063     0.013693                 158.61
# ...              ...          ...          ...                    ...
# 599         6.493000     0.000063     0.013693                 107.21
# 1599        2.270000     0.000137     0.029668                 288.64
# 1361        2.000000     0.000420     0.091287                 272.21
# 1547        2.000000     0.000420     0.091287                 287.98
# 863         0.624000     0.000084     0.018257                 181.06
#
# [1653 rows x 4 columns]
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# ...

# %% [markdown]
# ### Training and testing the model

# %%
model = IsolationForest(contamination=0.01,random_state=101)
train['anamoly']=model.fit_predict(train)
a=train.loc[train['anamoly']==-1]
test['anamoly']=model.predict(test)
y_pred=test['anamoly']
acc=(y_pred==-1).sum()/test.shape[0]
print("The Accuracy of the following anamoly detection unit is ", (1-acc)*100,"%")
avg+=acc
# Out:
# The Accuracy of the following anamoly detection unit is  98.91107078039929 %
# <ipython-input-29-bf5b250f45fd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['anamoly']=model.fit_predict(train)
# <ipython-input-29-bf5b250f45fd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['anamoly']=model.predict(test)

# %% [markdown]
# ### Transactions which has been marked as anamoly

# %%
(y_pred==-1).sum()
b=test.loc[test['anamoly']==-1]

c=pd.concat([a,b])
merged_left = pd.merge(left=dfs1, right=c, how='right',sort=True)
display(merged_left)
# Out:
#                                                Txhash  Blockno  UnixTimestamp  \
# 0   0x44a5fcf632280d7e2900d55171e4b7f01494faafc05b...  8573273     1568807817
# 1   0xdafde98ee0bddf70cdb2367a72c0937ef5c343b908f2...  6799349     1543567128
# 2   0x7b29286f9244e6a64890a74c2fa060f4d54ecdd24e39...  8572263     1568794139
# 3   0xe2b533da483d923e1030717b89bfc4abc4be501d71b1...  8573303     1568808248
# 4   0x01a8967af2c0bfc4371a3ef1f12ad195d71ffa37167c...  8573345     1568808789
# 5   0x23145f23cc626d7061938de9c45849ed6b15a02dec2a...  8573639     1568812451
# 6   0x877654eb5fecf7d11a63b0ad87f0d834b62521f543fb...  8571855     1568788899
# 7   0x14de4de371da1f09d1a9afd2d5cf8a358e3cf4e5f8ea...  7043269     1547136934
# 8   0x4ac6a2ef3a79bcffdb452425a6a5b0e65124e5f8036c...  7975389     1560767228
# 9   0x63acd3d57d3f0ebf78c38894278ac6b9df316bdf5aea...  8569553     1568758389
# 10  0x62bab3abeec4b630cf8b6591b445af52d0e381939102...  8162987     1563295067
# ...

# %% [markdown]
# ## Ethereuem Address 6
# ### 0x51C98d91C986204313B0D0E8c35F52bff590896d

# %%
dfs = pd.read_csv(r"D:\Desktop\nitk\6th_SEM\ML_Project\transaction_data\6_0x51C98d91C986204313B0D0E8c35F52bff590896d.csv")
dfs1=dfs
display(dfs)
# Out:
#                                                  Txhash  Blockno  \
# 0     0xef947e67741af293edb34479267e261bb3c077195a62...  7085023
# 1     0xa7238deca85e58b2ec66220bc8322f97ad7eda11b8ea...  7085577
# 2     0xe72b0e0e747825547f44b46c975736c25399faac4a0b...  7085839
# 3     0x5430600875b4ae68f1e11e0a4ea70cf3a8cf21e6baf3...  7086008
# 4     0x22775019bb2e08d99de7fd161c14bd8d3595dfe5e991...  7086076
# ...                                                 ...      ...
# 5026  0x9e604db24c2ed65bc1c301007b10a5bf830da7f5b9d4...  8570010
# 5027  0xb58428089d7cfebc6637abe0467c73f95da7a7339835...  8571651
# 5028  0x2b4e5398b632d15b586e34189bb91046df9f22028cec...  8576930
# 5029  0x1328902d42f0ac1bb0325e96e0d3fdb65cd342ff1935...  8577920
# 5030  0x6a281066c0322038040489f550e632570d4aac3cd0ff...  8584686
#
#       UnixTimestamp               DateTime  \
# 0        1547782088   1/18/2019 3:28:08 AM
# 1        1547790621   1/18/2019 5:50:21 AM
# 2        1547794774   1/18/2019 6:59:34 AM
# ...

# %% [markdown]
# ### Pre-Processing

# %%
dfs=dfs.drop(['Txhash','Blockno','UnixTimestamp','DateTime','From','To'],axis=1)
dfs=dfs.dropna()
display(dfs)
# Out:
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# 0           4.855000     0.000191     0.041524                 120.57
# 1           0.001120     0.000294     0.063883                 120.57
# 2           0.030000     0.000147     0.031942                 120.57
# 3           0.000800     0.000210     0.045631                 120.57
# 4           0.000744     0.000195     0.042437                 120.57
# ...              ...          ...          ...                    ...
# 5025        0.143474     0.000546     0.118618                 207.90
# 5026        0.518347     0.000336     0.072996                 207.90
# 5027        0.386300     0.000504     0.109494                 210.50
# 5028        0.756733     0.000315     0.068434                 221.29
# 5029        0.007583     0.000504     0.109494                 221.29
#
# [5030 rows x 4 columns]

# %% [markdown]
# ### Splitting the data

# %%
train, test = model_selection.train_test_split(dfs,test_size=0.25, random_state=101)
display(train)
display(test)
# Out:
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# 4276        0.000560     0.000147     0.031936                 309.41
# 555         0.000640     0.000168     0.036505                 134.29
# 4235        0.000480     0.000126     0.027374                 309.41
# 568         0.000560     0.000147     0.031942                 134.29
# 3391        0.000400     0.000105     0.022811                 163.94
# ...              ...          ...          ...                    ...
# 4171        1.270000     0.000126     0.027374                 309.41
# 599         2.144429     0.000126     0.027379                 143.29
# 1361        0.000560     0.000147     0.031942                 156.45
# 1547        0.000400     0.000105     0.022815                 158.36
# 4959        0.285614     0.000105     0.022811                 191.08
#
# [3772 rows x 4 columns]
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# ...

# %% [markdown]
# ### Training and testing the model

# %%
model = IsolationForest(contamination=0.01,random_state=101)
train['anamoly']=model.fit_predict(train)
a=train.loc[train['anamoly']==-1]
test['anamoly']=model.predict(test)
y_pred=test['anamoly']
acc=(y_pred==-1).sum()/test.shape[0]
print("The Accuracy of the following anamoly detection unit is ", (1-acc)*100,"%")
avg+=acc
# Out:
# The Accuracy of the following anamoly detection unit is  99.60254372019078 %
# <ipython-input-34-bf5b250f45fd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['anamoly']=model.fit_predict(train)
# <ipython-input-34-bf5b250f45fd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['anamoly']=model.predict(test)

# %% [markdown]
# ### Transactions which has been marked as anamoly

# %%
(y_pred==-1).sum()
b=test.loc[test['anamoly']==-1]

c=pd.concat([a,b])
merged_left = pd.merge(left=dfs1, right=c, how='right',sort=True)
display(merged_left)
# Out:
#                                                Txhash  Blockno  UnixTimestamp  \
# 0   0x9527cbb8a58a634a6c1212059c68297a90c94e4ec490...  8055397     1561846502
# 1   0x6bc70195839c19b5c1ca4ff617312d52e05e77874956...  8055405     1561846621
# 2   0x9527cbb8a58a634a6c1212059c68297a90c94e4ec490...  8055397     1561846502
# 3   0x6bc70195839c19b5c1ca4ff617312d52e05e77874956...  8055405     1561846621
# 4   0x179b54642c04166eda72da52a90c4c10e7e632b91f5b...  8032459     1561536604
# 5   0x840df0dbe3715c013cb860f0523f8f471e2deb8bd2f6...  7192421     1549619133
# 6   0x90017f94261f98cd0b8748c51840f008879f41261023...  8535127     1568294250
# 7   0xaadf31ecfb1925a36b2ba686d32f80e3c70966db4562...  7223908     1550242136
# 8   0x5cfe62ab26c34c47d0b19b0d98c93e4ad823efc9ecb9...  8567862     1568735842
# 9   0x8aef9634a8a59aeaa7cebc52d2ee9e437edb25bb289a...  8568022     1568738008
# 10  0x0b2c3eaf15621153e6b0cf9ca4462c2d0eedbf60312d...  8160510     1563261176
# ...

# %% [markdown]
# ## Ethereuem Address 7
# ### 0x337D61EDe4587cd2ad747E1afB13c31AA08E6903

# %%
dfs = pd.read_csv(r"D:\Desktop\nitk\6th_SEM\ML_Project\transaction_data\7_0x337D61EDe4587cd2ad747E1afB13c31AA08E6903.csv")
dfs1=dfs
display(dfs)
# Out:
#                                                  Txhash  Blockno  \
# 0     0x4f014121a8673cbd27d62a4adc81c2372c4ee9e518b0...  7164913
# 1     0xc4ff011e8ad171542d5769189e01eec9cb6f46c040ad...  7165143
# 2     0x6e58abd28bb52332bc878704f40d30a49b298c0c6fc9...  7167421
# 3     0x3cadfd36539993f2031ae873bb80ef43d2ceeb1ce236...  7168780
# 4     0x3f7b2bf04842a2d9aff8f25d4acea0f1e8e91c8c7b2c...  7169503
# ...                                                 ...      ...
# 2170  0x61e0b8f9e8493587b9aaf38e9aeb0319a10a3834449d...  8583070
# 2171  0x53acd67efe4195954a03cf195fb0bcece25e5666382b...  8583780
# 2172  0xf8f6b1a5d58eac9163ed33447a3862b1f126214374e3...  8583832
# 2173  0x35c8ddc5d7f95ea835fb82be8df7ea2d0625a24e3953...  8584200
# 2174  0x6cfe0ea1359944c27a9327500c751af8059ee03bf34f...  8585380
#
#       UnixTimestamp               DateTime  \
# 0        1549135482    2/2/2019 7:24:42 PM
# 1        1549139211    2/2/2019 8:26:51 PM
# 2        1549178380    2/3/2019 7:19:40 AM
# ...

# %% [markdown]
# ### Pre-Processing

# %%
dfs=dfs.drop(['Txhash','Blockno','UnixTimestamp','DateTime','From','To'],axis=1)
dfs=dfs.dropna()
display(dfs)
# Out:
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# 0            0.06070     0.000147     0.031971                 111.00
# 1            0.13194     0.000147     0.031971                 111.00
# 2            0.03600     0.000147     0.031971                 107.21
# 3            0.03600     0.000147     0.031971                 107.21
# 4            0.01000     0.000147     0.031971                 107.21
# ...              ...          ...          ...                    ...
# 2165         0.09070     0.000630     0.137019                 221.29
# 2166         0.09070     0.000630     0.137019                 221.29
# 2167         0.08810     0.000630     0.137019                 221.29
# 2168         1.04800     0.000630     0.137019                 221.29
# 2169         1.29630     0.000588     0.127884                 221.29
#
# [2170 rows x 4 columns]

# %% [markdown]
# ### Splitting the data

# %%
train, test = model_selection.train_test_split(dfs,test_size=0.25, random_state=101)
display(train)
display(test)
# Out:
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# 92           0.05000     0.000336     0.073077                 146.53
# 1809         0.01457     0.000105     0.022836                 188.46
# 720          1.09870     0.000325     0.070684                 267.42
# 146          0.00400     0.000231     0.050240                 149.23
# 1948         0.01020     0.000147     0.031971                 179.13
# ...              ...          ...          ...                    ...
# 599          0.05440     0.000126     0.027404                 163.61
# 1599         0.01457     0.000063     0.013702                 185.69
# 1361         0.05059     0.000105     0.022836                 225.99
# 1547         0.00800     0.000105     0.022836                 188.24
# 863          0.00230     0.000210     0.045673                 264.51
#
# [1627 rows x 4 columns]
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# ...

# %% [markdown]
# ### Training and testing the model

# %%
model = IsolationForest(contamination=0.01,random_state=101)
train['anamoly']=model.fit_predict(train)
a=train.loc[train['anamoly']==-1]
test['anamoly']=model.predict(test)
y_pred=test['anamoly']
acc=(y_pred==-1).sum()/test.shape[0]
print("The Accuracy of the following anamoly detection unit is ", (1-acc)*100,"%")
avg+=acc
# Out:
# The Accuracy of the following anamoly detection unit is  98.89502762430939 %
# <ipython-input-39-bf5b250f45fd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['anamoly']=model.fit_predict(train)
# <ipython-input-39-bf5b250f45fd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['anamoly']=model.predict(test)

# %% [markdown]
# ### Transactions which has been marked as anamoly

# %%
(y_pred==-1).sum()
b=test.loc[test['anamoly']==-1]

c=pd.concat([a,b])
merged_left = pd.merge(left=dfs1, right=c, how='right',sort=True)
display(merged_left)
# Out:
#                                                Txhash  Blockno  UnixTimestamp  \
# 0   0x7381099995bb21794969742ca4ad893ea7b4feaace08...  8579901     1568897386
# 1   0x5a1196727b13cbd0f53fd3a33677e856662d9c1bdb40...  8580900     1568910911
# 2   0xcf987c5345ece632270b03c435ea3bebe95028a6e5d1...  8580731     1568908628
# 3   0x556ae701af54b2913e799857f2e4abb55ae662a9a89e...  8580763     1568908990
# 4   0xcf987c5345ece632270b03c435ea3bebe95028a6e5d1...  8580731     1568908628
# 5   0x556ae701af54b2913e799857f2e4abb55ae662a9a89e...  8580763     1568908990
# 6   0x19e334fa36f8f682123965e7a655d9b147509b34a916...  8573048     1568804582
# 7   0xada3a553e9017c359c8dc58f5b55778f2863c42848ee...  8573158     1568806180
# 8   0xfc60451c2c691e13487bd0e4888ed052da63d993634b...  8580707     1568908259
# 9   0x54219b92bc987543c07e9d12a987817bf6de17da240e...  8581026     1568912687
# 10  0x3a7f20e255229e0c5e73413739c5c605ba9e17f7bfb6...  8580053     1568899409
# ...

# %% [markdown]
# ## Ethereuem Address 8
# ### 0x261d363D235E2a91B7E208c244163148277aB9Cf

# %%
dfs = pd.read_csv(r"D:\Desktop\nitk\6th_SEM\ML_Project\transaction_data\8_0x261d363D235E2a91B7E208c244163148277aB9Cf.csv")
dfs1=dfs
display(dfs)
# Out:
#                                                  Txhash  Blockno  \
# 0     0x9452e0ef765b289c0a4854adb121533fd927b8687b2f...  5015764
# 1     0x82659eb9ce2b715865fbab4d453563c906fb13fd9d78...  5398075
# 2     0x529caa347a548e13f41bdb1f08b4c2174d523fa10a67...  5446477
# 3     0xc246e73602c715870a8a163ed97c0e03415013f9cc89...  5457211
# 4     0xaa6fbae4ab847c8a6ac621bf662cc9e2173860f76e4a...  5457480
# ...                                                 ...      ...
# 2319  0xc2157b8c250de7b77bebcb9f8da53582a927403346d3...  8580463
# 2320  0xe332a88120a4132e11c9889bb70c43b3a234226825e9...  8580497
# 2321  0x59fd32bdc28739b562824983eead45d195058e44ac52...  8581043
# 2322  0xa6923d635ee51f4285decacda93a98f48b3ae8989cce...  8585265
# 2323  0x8f90f34092662c2eaac5afd2f9f1899cda7770256eec...  8585286
#
#       UnixTimestamp              DateTime  \
# 0        1517553079   2/2/2018 6:31:19 AM
# 1        1523117108   4/7/2018 4:05:08 PM
# 2        1523817229  4/15/2018 6:33:49 PM
# ...

# %% [markdown]
# ### Pre-Processing

# %%
dfs=dfs.drop(['Txhash','Blockno','UnixTimestamp','DateTime','From','To'],axis=1)
dfs=dfs.dropna()
display(dfs)
# Out:
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# 0           2.045577     0.000840     0.182624                 917.47
# 1           0.040000     0.000840     0.182624                 384.98
# 2         100.000000     0.000840     0.182624                 534.15
# 3           0.109000     0.000840     0.182624                 503.03
# 4           0.005000     0.000840     0.182624                 503.03
# ...              ...          ...          ...                    ...
# 2317        0.500000     0.000525     0.114109                 221.29
# 2318        0.100000     0.000546     0.118673                 221.29
# 2319        0.055000     0.000462     0.100416                 221.29
# 2320        0.100000     0.000466     0.101329                 221.29
# 2321        0.100000     0.000525     0.114109                 221.29
#
# [2322 rows x 4 columns]

# %% [markdown]
# ### Splitting the data

# %%
train, test = model_selection.train_test_split(dfs,test_size=0.25, random_state=101)
display(train)
display(test)
# Out:
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# 1150        0.130000      0.00021     0.045644                 254.94
# 1614        0.052000      0.00042     0.091287                 221.28
# 1343        0.150000      0.00021     0.045644                 231.43
# 1515        0.550000      0.00021     0.045644                 309.37
# 1981        1.000000      0.00021     0.045644                 188.46
# ...              ...          ...          ...                    ...
# 599        10.000000      0.00021     0.045656                 120.57
# 1599        0.190000      0.00021     0.045644                 226.09
# 1361        0.100000      0.00021     0.045644                 263.76
# 1547        0.050000      0.00021     0.045644                 307.89
# 863         0.207609      0.00021     0.045656                 166.28
#
# [1741 rows x 4 columns]
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# ...

# %% [markdown]
# ### Training and testing the model

# %%
model = IsolationForest(contamination=0.01,random_state=101)
train['anamoly']=model.fit_predict(train)
a=train.loc[train['anamoly']==-1]
test['anamoly']=model.predict(test)
y_pred=test['anamoly']
acc=(y_pred==-1).sum()/test.shape[0]
print("The Accuracy of the following anamoly detection unit is ", (1-acc)*100,"%")
avg+=acc
# Out:
# <ipython-input-44-bf5b250f45fd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['anamoly']=model.fit_predict(train)
# The Accuracy of the following anamoly detection unit is  98.9672977624785 %
# <ipython-input-44-bf5b250f45fd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['anamoly']=model.predict(test)

# %% [markdown]
# ### Transactions which has been marked as anamoly

# %%
(y_pred==-1).sum()
b=test.loc[test['anamoly']==-1]

c=pd.concat([a,b])
merged_left = pd.merge(left=dfs1, right=c, how='right',sort=True)
display(merged_left)
# Out:
#                                                Txhash  Blockno  UnixTimestamp  \
# 0   0x33b7d992bc8307fd4eb7a9d33d24d78cf69a8520a174...  6110532     1533732407
# 1   0x3a0d6beaafde7135625b89866d24cd2599b0a3b857b5...  8545945     1568440715
# 2   0xcc2d6e755055c1b995a6d1bf84fe24d4d1044d040c98...  6111042     1533739999
# 3   0x5ab4985e1473a6828b4c8f339b60b83564a269299fdb...  5885239     1530429668
# 4   0x80e47ff7a69d3b4f87bd61019751263e0fb14b73d2de...  5594049     1526027363
# 5   0x43eacc12b74c0417fd5b8fe672f04c4a7b1e92f34100...  5477841     1524282226
# 6   0xdd8a4d0574606928ac4b4ba0e1ff2234705cc72843b4...  6232254     1535509965
# 7   0x13a65c323ffd46969550c9d641b6bfeac66b8f6adc47...  6232330     1535511111
# 8   0xdd8a4d0574606928ac4b4ba0e1ff2234705cc72843b4...  6232254     1535509965
# 9   0x13a65c323ffd46969550c9d641b6bfeac66b8f6adc47...  6232330     1535511111
# 10  0x045cca75a6c97b9f7774ee5ef8cc882587bfe7145758...  6111524     1533746912
# ...

# %% [markdown]
# ## Ethereuem Address 9
# ### 0xFa453aec042a837e4AEBbADAB9d4E25B15FAd69D

# %%
dfs = pd.read_csv(r"D:\Desktop\nitk\6th_SEM\ML_Project\transaction_data\9_0xFa453aec042a837e4AEBbADAB9d4E25B15FAd69D.csv")
dfs1=dfs
display(dfs)
# Out:
#                                                  Txhash  Blockno  \
# 0     0x9d409af83740d82db859176c49e6442258363ddf34c7...  6737729
# 1     0xf2f161e92d6014540f070003abb1b9daa550d249f5c6...  6739382
# 2     0xf948e2ece1c414ec14ea2b25fdd2afacc129ba68388c...  6834725
# 3     0xe63682e80dbecd84faef34ff9f4b880a3c6663fadc85...  6841008
# 4     0x4ce96429c0c8fa7bafd19cde8663cf939e00fc7a7a6e...  6848573
# ...                                                 ...      ...
# 2086  0x8557bc346da0d422a6d6097cf069b2746ddbab1792bd...  8581881
# 2087  0x862c1e76f88bb97ed83869bcbecdf62e5634d9d37836...  8581881
# 2088  0x539e9d72db9b77453a9021425919ee20e3419f6a3bfa...  8583053
# 2089  0x0dc511202030bff48a8c083fec080e45476c3a85b235...  8583576
# 2090  0x28aad84c5eb43b2dc9fe8243c5f2c42215ad707dae6d...  8583710
#
#       UnixTimestamp                DateTime  \
# 0        1542691074   11/20/2018 5:17:54 AM
# 1        1542715060  11/20/2018 11:57:40 AM
# 2        1544072721    12/6/2018 5:05:21 AM
# ...

# %% [markdown]
# ### Pre-Processing

# %%
dfs=dfs.drop(['Txhash','Blockno','UnixTimestamp','DateTime','From','To'],axis=1)
dfs=dfs.dropna()
display(dfs)
# Out:
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# 0              9.800     0.000126     0.027449                 130.74
# 1              0.001     0.000210     0.045637                 130.74
# 2            300.000     0.000128     0.027839                  90.43
# 3              0.001     0.000107     0.023275                  93.61
# 4            670.000     0.000084     0.018255                  91.44
# ...              ...          ...          ...                    ...
# 2083         233.000     0.001050     0.228186                 221.29
# 2084        1164.000     0.001050     0.228186                 221.29
# 2085         465.000     0.001050     0.228186                 221.29
# 2086         513.000     0.001050     0.228186                 221.29
# 2087         653.000     0.001050     0.228186                 221.29
#
# [2088 rows x 4 columns]

# %% [markdown]
# ### Splitting the data

# %%
train, test = model_selection.train_test_split(dfs,test_size=0.25, random_state=101)
display(train)
display(test)
# Out:
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# 1904           0.001     0.001050     0.228186                 178.76
# 1563           0.001     0.001050     0.228186                 219.41
# 195            0.001     0.000063     0.013691                 170.66
# 1209           0.001     0.000781     0.169770                 268.94
# 1294           0.001     0.000252     0.054765                 268.94
# ...              ...          ...          ...                    ...
# 599          949.000     0.000983     0.213582                 309.41
# 1599           0.001     0.000252     0.054765                 219.23
# 1361           0.001     0.000252     0.054765                 226.16
# 1547           0.001     0.001050     0.228186                 216.66
# 863            0.001     0.001050     0.228186                 268.56
#
# [1566 rows x 4 columns]
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# ...

# %% [markdown]
# ### Training and testing the model

# %%
model = IsolationForest(contamination=0.01,random_state=101)
train['anamoly']=model.fit_predict(train)
a=train.loc[train['anamoly']==-1]
test['anamoly']=model.predict(test)
y_pred=test['anamoly']
acc=(y_pred==-1).sum()/test.shape[0]
print("The Accuracy of the following anamoly detection unit is ", (1-acc)*100,"%")
avg+=acc
# Out:
# The Accuracy of the following anamoly detection unit is  99.23371647509579 %
# <ipython-input-49-bf5b250f45fd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['anamoly']=model.fit_predict(train)
# <ipython-input-49-bf5b250f45fd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['anamoly']=model.predict(test)

# %% [markdown]
# ### Transactions which has been marked as anamoly

# %%
(y_pred==-1).sum()
b=test.loc[test['anamoly']==-1]

c=pd.concat([a,b])
merged_left = pd.merge(left=dfs1, right=c, how='right',sort=True)
display(merged_left)
# Out:
#                                                Txhash  Blockno  UnixTimestamp  \
# 0   0x31ea03be59dca3cdc626411e04a91f3edb2f185726e4...  8264767     1564661977
# 1   0xa4194da05156bf2735ad22c8700ec792825760dd9f72...  8115403     1562653288
# 2   0x01bf3314e23db153059e7206cff2213af91d6a351aca...  7994394     1561024681
# 3   0x0f2789f54bfe94326baa061f380288107f8803897cb5...  7975130     1560763685
# 4   0x2332d2c21ce40cdeeea177d9ac7387f5709f9954e070...  8001183     1561116207
# 5   0x60deffaea7df317037bc86451609c7385e07723c408e...  8378595     1566187705
# 6   0x97bdb76658ccc444495eb05d7a8dbd14240c90c35894...  8039173     1561627688
# 7   0x22ba46daad58a3a40367619775ea0953cf0af2463921...  8353524     1565850805
# 8   0xb9fbc64a873130d63433f8297d578bf5ae72f4028a2c...  7975674     1560771108
# 9   0xc7c44d7b704d1278c4a8306acf712aee1c1399e66a27...  7991603     1560986473
# 10  0x07da1012ca26eee783d36b494860d32e784b361849fe...  8035193     1561573641
# ...

# %% [markdown]
# ## Ethereuem Address 10
# ### 0xFC04F920C7195B75FBb3b387C9A3dbFA8d10F651

# %%
dfs = pd.read_csv(r"D:\Desktop\nitk\6th_SEM\ML_Project\transaction_data\10_0xFC04F920C7195B75FBb3b387C9A3dbFA8d10F651.csv")
dfs1=dfs
display(dfs)
# Out:
#                                                  Txhash  Blockno  \
# 0     0x7ce58942634630bfb37801b36a085dd025cd0f5910dc...  5529503
# 1     0x98009e7679d86d9acc87f033e7b6a43ed9a40b14b126...  5530798
# 2     0x929b2d61ce5828342a4b4367e59458372d918c1463d6...  5531268
# 3     0x841874c74fc0f9af7055ef6ec7596a724186e8709832...  5531453
# 4     0x4bc4db6600c23a49f6a623b8817e9b13a984b722e0bd...  5532083
# ...                                                 ...      ...
# 2861  0xae4c1e0aa2c25a1edd233e31000b6b0556ddd58e2e94...  8496129
# 2862  0x441b057a1c9a7f08ebd211e8f7dcc12f0d07ccf1a26c...  8496577
# 2863  0xb9d3aaaceac5af50bab97a21750530554d6a02bc5195...  8507937
# 2864  0x749348cc3fc56d44a81aa1f6204e2cbdef932c1bcc87...  8514664
# 2865  0xd302fc298f365deb10ec56816d98a851ec6ca7f9df53...  8515134
#
#       UnixTimestamp               DateTime  \
# 0        1525051781   4/30/2018 1:29:41 AM
# 1        1525071348   4/30/2018 6:55:48 AM
# 2        1525078651   4/30/2018 8:57:31 AM
# ...

# %% [markdown]
# ### Pre-Processing

# %%
dfs=dfs.drop(['Txhash','Blockno','UnixTimestamp','DateTime','From','To'],axis=1)
dfs=dfs.dropna()
display(dfs)
# Out:
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# 0           4.370434     0.000164     0.035679                 670.04
# 1           4.994791     0.000204     0.044242                 670.04
# 2           4.159414     0.000204     0.044242                 670.04
# 3           4.100858     0.000328     0.071358                 670.04
# 4           4.586255     0.000230     0.049950                 670.04
# ...              ...          ...          ...                    ...
# 2861       17.585908     0.000713     0.154833                 169.47
# 2862       14.273986     0.000784     0.170316                 169.47
# 2863       17.999538     0.000499     0.108383                 181.67
# 2864       19.999461     0.000534     0.116125                 180.84
# 2865        3.756728     0.000713     0.154833                 180.84
#
# [2866 rows x 4 columns]

# %% [markdown]
# ## Splitting the data

# %%
train, test = model_selection.train_test_split(dfs,test_size=0.25, random_state=101)
display(train)
display(test)
# Out:
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# 369         3.094432     0.000053     0.011417                 408.81
# 776         8.441675     0.000356     0.077418                 225.26
# 969         4.101445     0.000285     0.061933                 211.29
# 168         3.277096     0.000099     0.021479                 453.42
# 452         3.907891     0.000249     0.054191                 288.02
# ...              ...          ...          ...                    ...
# 599         4.663649     0.000214     0.046450                 220.12
# 1599       10.333396     0.000356     0.077416                 134.28
# 1361        7.831752     0.000321     0.069675                 139.73
# 1547        8.508002     0.000285     0.061936                 119.49
# 863        10.563648     0.000356     0.077416                 201.23
#
# [2149 rows x 4 columns]
#       Value_OUT(ETH)  TxnFee(ETH)  TxnFee(USD)  Historical $Price/Eth
# ...

# %% [markdown]
# ### Training and testing the model

# %%
model = IsolationForest(contamination=0.01,random_state=101)
train['anamoly']=model.fit_predict(train)
a=train.loc[train['anamoly']==-1]
test['anamoly']=model.predict(test)
y_pred=test['anamoly']
acc=(y_pred==-1).sum()/test.shape[0]
print("The Accuracy of the following anamoly detection unit is ", (1-acc)*100,"%")
avg+=acc
# Out:
# <ipython-input-54-bf5b250f45fd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['anamoly']=model.fit_predict(train)
# <ipython-input-54-bf5b250f45fd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['anamoly']=model.predict(test)
# The Accuracy of the following anamoly detection unit is  98.88423988842399 %

# %% [markdown]
# ### Transactions which has been marked as anamoly

# %%
(y_pred==-1).sum()
b=test.loc[test['anamoly']==-1]

c=pd.concat([a,b])
merged_left = pd.merge(left=dfs1, right=c, how='right',sort=True)
display(merged_left)
# Out:
#                                                Txhash  Blockno  UnixTimestamp  \
# 0   0xceeb8110b9352de10443b09a4533b7600b4504a9fead...  6162811     1534495991
# 1   0xb22738ce170b6234ebb94c736120f473b50626a7bcee...  5880869     1530364496
# 2   0xf2e455c4d108fe21ad55c2ee243ce7cd43a9c5096701...  5890908     1530512115
# 3   0xde7aff23bcdcccd8875d8706c3a344abf828de8c72a5...  6108640     1533705213
# 4   0x71f4dba9938281563f7586fdceaa4f60c9628866d1e6...  6112139     1533755727
# 5   0xb7952f3daedb63326dea16642836dc4a441240d3fdae...  6108196     1533698558
# 6   0x9e5afaa2a6303b164ea05e811019704d0a541cc01d87...  6111096     1533740688
# 7   0xc776cd98444ccb797c2d3ebd5c3440ddbde00b140e3c...  5898692     1530627013
# 8   0x5a256711f1321ee85fe023a90a83c1e59f0e7f77d720...  5895985     1530586908
# 9   0x4cf9edf82821f9737090b5b245318c627201d91284c4...  5897866     1530614869
# 10  0xf186898bb8d5f03271277e7482b5890163bd0685f433...  5896155     1530589355
# ...

# %%
print("The average accuracies of all the transaction is",100-avg*10)
# Out:
# The average accuracies of all the transaction is 99.21085672087055
